# %%
#Import goodbooks dataset with additional fields (see separate google colab notebook with the scraping code here : https://colab.research.google.com/drive/1AVD1QMp1hnqKmVjsVRUQ3HRUo4lqNBKP?usp=sharing
import pandas as pd
from ast import literal_eval

books_df = pd.read_csv('https://raw.githubusercontent.com/malcolmosh/MATH80629/main/books_enrichedv2.csv', index_col=[0], converters={"genres": literal_eval})

# head
display(books_df.head())
# Out:
#    index                      authors  average_rating  best_book_id  book_id  \
# 0      0              Suzanne Collins            4.34       2767052        1
# 1      1  J.K. Rowling, Mary GrandPré            4.44             3        2
# 2      2              Stephenie Meyer            3.57         41865        3
# 3      3                   Harper Lee            4.25          2657        4
# 4      4          F. Scott Fitzgerald            3.89          4671        5
#
#    books_count                                        description  \
# 0          272  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1          491  Harry Potter's life is miserable. His parents ...
# 2          226  About three things I was absolutely positive.\...
# 3          487  The unforgettable novel of a childhood in a sl...
# 4         1356  Alternate Cover Edition ISBN: 0743273567 (ISBN...
#
#                                               genres  goodreads_book_id  \
# 0  [young-adult, fiction, dystopia, fantasy, scie...            2767052
# 1  [fantasy, fiction, young-adult, magic, childre...                  3
# 2  [young-adult, fantasy, romance, vampires, fict...              41865
# 3  [classics, fiction, historical-fiction, school...               2657
# 4  [classics, fiction, school, literature, histor...               4671
#
#                                            image_url  ... ratings_2  \
# 0  https://images.gr-assets.com/books/1447303603m...  ...    127936
# 1  https://images.gr-assets.com/books/1474154022m...  ...    101676
# 2  https://images.gr-assets.com/books/1361039443m...  ...    436802
# 3  https://images.gr-assets.com/books/1361975680m...  ...    117415
# 4  https://images.gr-assets.com/books/1490528560m...  ...    197621
#
#    ratings_3 ratings_4  ratings_5 ratings_count  \
# 0     560092   1481305    2706317       4780653
# 1     455024   1156318    3011543       4602479
# 2     793319    875073    1355439       3866839
# 3     446835   1001952    1714267       3198671
# 4     606158    936012     947718       2683664
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#                                                title  work_id  \
# 0            The Hunger Games (The Hunger Games, #1)  2792775
# 1  Harry Potter and the Sorcerer's Stone (Harry P...  4640799
# 2                            Twilight (Twilight, #1)  3212258
# 3                              To Kill a Mockingbird  3275794
# 4                                   The Great Gatsby   245494
#
#    work_ratings_count  work_text_reviews_count
# 0             4942365                   155254
# 1             4800065                    75867
# 2             3916824                    95009
# 3             3340896                    72586
# 4             2773745                    51992
#
# [5 rows x 28 columns]

# %%
books_df['language_code'].unique()
# Out:
# array(['eng', 'en-US', 'en-CA', nan, 'en-GB', 'spa', 'fre', 'ara', 'por',
#        'ger', 'nor', 'jpn', 'vie', 'en', 'ind', 'pol', 'tur', 'dan',
#        'fil', 'ita', 'per', 'swe', 'rum', 'mul', 'rus', 'nl'],
#       dtype=object)

# %%
df = books_df.dropna(subset=["average_rating", "ratings_count", "description", "genres", "original_publication_year"])
df.head()
# Out:
#    index                      authors  average_rating  best_book_id  book_id  \
# 0      0              Suzanne Collins            4.34       2767052        1
# 1      1  J.K. Rowling, Mary GrandPré            4.44             3        2
# 2      2              Stephenie Meyer            3.57         41865        3
# 3      3                   Harper Lee            4.25          2657        4
# 4      4          F. Scott Fitzgerald            3.89          4671        5
#
#    books_count                                        description  \
# 0          272  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1          491  Harry Potter's life is miserable. His parents ...
# 2          226  About three things I was absolutely positive.\...
# 3          487  The unforgettable novel of a childhood in a sl...
# 4         1356  Alternate Cover Edition ISBN: 0743273567 (ISBN...
#
#                                               genres  goodreads_book_id  \
# 0  [young-adult, fiction, dystopia, fantasy, scie...            2767052
# 1  [fantasy, fiction, young-adult, magic, childre...                  3
# 2  [young-adult, fantasy, romance, vampires, fict...              41865
# 3  [classics, fiction, historical-fiction, school...               2657
# 4  [classics, fiction, school, literature, histor...               4671
#
#                                            image_url  ... ratings_2  \
# 0  https://images.gr-assets.com/books/1447303603m...  ...    127936
# 1  https://images.gr-assets.com/books/1474154022m...  ...    101676
# 2  https://images.gr-assets.com/books/1361039443m...  ...    436802
# 3  https://images.gr-assets.com/books/1361975680m...  ...    117415
# 4  https://images.gr-assets.com/books/1490528560m...  ...    197621
#
#    ratings_3 ratings_4  ratings_5 ratings_count  \
# 0     560092   1481305    2706317       4780653
# 1     455024   1156318    3011543       4602479
# 2     793319    875073    1355439       3866839
# 3     446835   1001952    1714267       3198671
# 4     606158    936012     947718       2683664
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#                                                title  work_id  \
# 0            The Hunger Games (The Hunger Games, #1)  2792775
# 1  Harry Potter and the Sorcerer's Stone (Harry P...  4640799
# 2                            Twilight (Twilight, #1)  3212258
# 3                              To Kill a Mockingbird  3275794
# 4                                   The Great Gatsby   245494
#
#    work_ratings_count  work_text_reviews_count
# 0             4942365                   155254
# 1             4800065                    75867
# 2             3916824                    95009
# 3             3340896                    72586
# 4             2773745                    51992
#
# [5 rows x 28 columns]

# %%
median_ratings = df['ratings_count'].median()
print(median_ratings)
df['popular_book'] = (df['ratings_count'] > median_ratings).astype(int)
# Out:
# 21244.5
# /var/folders/7n/jwm4385x755fzh0cx71493140000gn/T/ipykernel_81925/1631193936.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['popular_book'] = (df['ratings_count'] > median_ratings).astype(int)

# %%
#best reviewed books

#get top 20 books
books_df_pop = books_df.sort_values(['average_rating'], ascending = False).iloc[0:20,]

#draw table
books_df_pop[["title","authors","average_rating"]].reset_index(drop=True)
# Out:
#                                                 title  \
# 0                      The Complete Calvin and Hobbes
# 1   Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 2      Words of Radiance (The Stormlight Archive, #2)
# 3                                     ESV Study Bible
# 4                            Mark of the Lion Trilogy
# 5   It's a Magical World: A Calvin and Hobbes Coll...
# 6            Harry Potter Boxset (Harry Potter, #1-7)
# 7   There's Treasure Everywhere: A Calvin and Hobb...
# 8   The Authoritative Calvin and Hobbes: A Calvin ...
# 9        Harry Potter Collection (Harry Potter, #1-6)
# 10                The Indispensable Calvin and Hobbes
# 11  A Court of Mist and Fury (A Court of Thorns an...
# 12  Attack of the Deranged Mutant Killer Monster S...
# 13    Preach My Gospel: A Guide To Missionary Service
# 14                        The Revenge of the Baby-Sat
# 15  Homicidal Psycho Jungle Cat: A Calvin and Hobb...
# 16  The Days Are Just Packed: A Calvin and Hobbes ...
# 17                  Life Application Study Bible: NIV
# 18  The Way of Kings, Part 1 (The Stormlight Archi...
# 19           The Holy Bible: English Standard Version
#
#                                             authors  average_rating
# 0                                    Bill Watterson            4.82
# 1                       J.K. Rowling, Mary GrandPré            4.77
# 2                                 Brandon Sanderson            4.77
# 3        Anonymous, Lane T. Dennis, Wayne A. Grudem            4.76
# 4                                   Francine Rivers            4.76
# 5                                    Bill Watterson            4.75
# 6                                      J.K. Rowling            4.74
# 7                                    Bill Watterson            4.74
# 8                                    Bill Watterson            4.73
# 9                                      J.K. Rowling            4.73
# 10                                   Bill Watterson            4.73
# 11                                    Sarah J. Maas            4.72
# 12                                   Bill Watterson            4.72
# 13  The Church of Jesus Christ of Latter-day Saints            4.71
# 14                                   Bill Watterson            4.71
# 15                                   Bill Watterson            4.71
# 16                                   Bill Watterson            4.68
# 17      Anonymous, Ronald A. Beers, Ronald A. Beers            4.67
# 18                                Brandon Sanderson            4.67
# 19                                        Anonymous            4.66
